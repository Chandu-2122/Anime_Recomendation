# %% [markdown]
# ## Description
#
# For creating a Anime recommendation model, we need to specifically know about these concepts:
#
# 1. Feature Extraction: The mapping from textual data to real valued vectors is called feature extraction.
# 2. Bag Of Words(BOW): It is the list of unique woreds in the text corpus.
# 3. **TfidfVectorizer()**-Term Frequency Inverse Document Frequency: This function helps us to convert the text into vectors by counting the number of times each word appeared in a document.
#
#   TF-IDF value of a term = TF x IDF
# 4. Term frequency(TF) = (Number of times term 't' appears in a document)/(Number of terms in the document)
# 5. Inverse Document Frequency(IDF) = log(N/n), where, 'N' is the number of documents and 'n' is the number of documents a term 't' has appeared in.
#
#   The IDF value of a rare word is high, whereas the IDF of a frequent word is low.
# 6. **Cosine Similarity**: It is dot product of the two two vectors divided by the product of the two vectors' lengths(or magnitudes).
#
#   It gives a similarity score of a given anime, compares it with all other animes' similarity scores and hence gives the anime name with the highest similarity score.
# 7. **difflib**: It gives the closest match of a given value.

# %%
#importing all the necessary libraries

import pandas as pd

dataset = pd.read_csv('/content/Anime.csv')

# %%
#now we have imported the dataset, let's view it

dataset
# Out:
#         Rank                                               Name  \
# 0          1  Demon Slayer: Kimetsu no Yaiba - Entertainment...
# 1          2                     Fruits Basket the Final Season
# 2          3                                    Mo Dao Zu Shi 3
# 3          4                   Fullmetal Alchemist: Brotherhood
# 4          5                Attack on Titan 3rd Season: Part II
# ...      ...                                                ...
# 18490  18491  Qin Shi Mingyue: Canghai Hengliu Xiaomeng Spec...
# 18491  18492                      Yi Tang Juchang: Sanguo Yanyi
# 18492  18493          Fenghuang Ji Xiang Yu Qingming Shanghe Tu
# 18493  18494                      Chengshi Jiyi Wo Men de Jieri
# 18494  18495  Heisei Inu Monogatari Bow: Genshi Inu Monogata...
#
#                                          Japanese_name   Type  Episodes  \
# 0                        Kimetsu no Yaiba: Yuukaku-hen  TV          NaN
# 1                              Fruits Basket the Final  TV         13.0
# 2                           The Founder of Diabolism 3  Web        12.0
# 3       Hagane no Renkinjutsushi: Full Metal Alchemist  TV         64.0
# 4                 Shingeki no Kyojin Season 3: Part II  TV         10.0
# ...                                                ...    ...       ...
# 18490                                              NaN  Web         2.0
# 18491                                              NaN  TV        108.0
# 18492                                              NaN  TV         13.0
# 18493                                              NaN  TV          NaN
# 18494                                              NaN  Movie       NaN
#
#                              Studio Release_season  \
# 0                          ufotable          Fall
# 1                 TMS Entertainment         Spring
# 2                  B.C MAY PICTURES            NaN
# 3                             Bones         Spring
# 4                        WIT Studio         Spring
# ...                             ...            ...
# 18490  Sparkly Key Animation Studio            NaN
# 18491                           NaN            NaN
# 18492                           NaN            NaN
# 18493                           NaN            NaN
# 18494              Nippon Animation            NaN
#
#                                                     Tags  Rating  \
# 0      Action, Adventure, Fantasy, Shounen, Demons, H...    4.60
# 1      Drama, Fantasy, Romance, Shoujo, Animal Transf...    4.60
# 2      Fantasy, Ancient China, Chinese Animation, Cul...    4.58
# 3      Action, Adventure, Drama, Fantasy, Mystery, Sh...    4.58
# 4      Action, Fantasy, Horror, Shounen, Dark Fantasy...    4.57
# ...                                                  ...     ...
# 18490  Action, Ancient China, Chinese Animation, Hist...     NaN
# 18491                                  Chinese Animation     NaN
# 18492  Chinese Animation, Family Friendly, Short Epis...     NaN
# 18493  Chinese Animation, Family Friendly, Short Epis...     NaN
# 18494                        Comedy, Slice of Life, Dogs     NaN
#
#        Release_year  End_year  \
# 0            2021.0       NaN
# 1            2021.0       NaN
# 2            2021.0       NaN
# 3            2009.0    2010.0
# 4            2019.0       NaN
# ...             ...       ...
# 18490        2020.0       NaN
# 18491        2010.0       NaN
# 18492        2020.0       NaN
# 18493        2020.0       NaN
# 18494        1994.0       NaN
#
#                                              Description  \
# 0      'Tanjiro and his friends accompany the Hashira...
# 1                      'The final arc of Fruits Basket.'
# 2                   'The third season of Mo Dao Zu Shi.'
# 3      "The foundation of alchemy is based on the law...
# 4      'The battle to retake Wall Maria begins now! W...
# ...                                                  ...
# 18490  Special episodes of Qin Shi Mingyue: Canghai H...
# 18491                 No synopsis yet - check back soon!
# 18492                 No synopsis yet - check back soon!
# 18493                 No synopsis yet - check back soon!
# 18494                 No synopsis yet - check back soon!
#
#                                          Content_Warning  \
# 0                                      Explicit Violence
# 1      Emotional Abuse,, Mature Themes,, Physical Abu...
# 2                                                    NaN
# 3      Animal Abuse,, Mature Themes,, Violence,, Dome...
# 4                        Cannibalism,, Explicit Violence
# ...                                                  ...
# 18490                                                NaN
# 18491                                                NaN
# 18492                                                NaN
# 18493                                                NaN
# 18494                                                NaN
#
#                                            Related_Mange  \
# 0                         Demon Slayer: Kimetsu no Yaiba
# 1                   Fruits Basket, Fruits Basket Another
# 2      Grandmaster of Demonic Cultivation: Mo Dao Zu ...
# 3      Fullmetal Alchemist, Fullmetal Alchemist (Ligh...
# 4      Attack on Titan, Attack on Titan: End of the W...
# ...                                                  ...
# 18490                                                NaN
# 18491                                                NaN
# 18492                                                NaN
# 18493                                                NaN
# 18494                                                NaN
#
#                                            Related_anime  \
# 0      Demon Slayer: Kimetsu no Yaiba, Demon Slayer: ...
# 1      Fruits Basket 1st Season, Fruits Basket 2nd Se...
# 2                       Mo Dao Zu Shi 2, Mo Dao Zu Shi Q
# 3      Fullmetal Alchemist: Brotherhood Specials, Ful...
# 4      Attack on Titan, Attack on Titan 2nd Season, A...
# ...                                                  ...
# 18490                   Qin Shi Mingyue: Canghai Hengliu
# 18491                                                NaN
# 18492                                                NaN
# 18493                                                NaN
# 18494                          Heisei Inu Monogatari Bow
#
#                                             Voice_actors  \
# 0      Inosuke Hashibira : Yoshitsugu Matsuoka, Nezuk...
# 1      Akito Sohma : Maaya Sakamoto, Kyo Sohma : Yuum...
# 2      Lan Wangji, Wei Wuxian, Jiang Cheng, Jin Guang...
# 3      Alphonse Elric : Rie Kugimiya, Edward Elric : ...
# 4      Armin Arlelt : Marina Inoue, Eren Jaeger : Yuu...
# ...                                                  ...
# 18490                                                NaN
# 18491                                                NaN
# 18492                                                NaN
# 18493                                                NaN
# 18494                                                NaN
#
#                                                    staff
# 0      Koyoharu Gotouge : Original Creator, Haruo Sot...
# 1      Natsuki Takaya : Original Creator, Yoshihide I...
# 2      Mo Xiang Tong Xiu : Original Creator, Xiong Ke...
# 3      Hiromu Arakawa : Original Creator, Yasuhiro Ir...
# 4      Hajime Isayama : Original Creator, Tetsurou Ar...
# ...                                                  ...
# 18490                                                NaN
# 18491                                                NaN
# 18492                                                NaN
# 18493                                                NaN
# 18494                                                NaN
#
# [18495 rows x 17 columns]

# %%
#let's see the basic information of our dataset

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18495 entries, 0 to 18494
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             18495 non-null  int64
#  1   Name             18495 non-null  object
#  2   Japanese_name    7938 non-null   object
#  3   Type             18495 non-null  object
#  4   Episodes         9501 non-null   float64
#  5   Studio           12018 non-null  object
#  6   Release_season   4116 non-null   object
#  7   Tags             18095 non-null  object
#  8   Rating           15364 non-null  float64
#  9   Release_year     18112 non-null  float64
#  10  End_year         2854 non-null   float64
#  11  Description      18491 non-null  object
#  12  Content_Warning  1840 non-null   object
#  13  Related_Mange    7627 non-null   object
#  14  Related_anime    10063 non-null  object
#  15  Voice_actors     15309 non-null  object
#  16  staff            13005 non-null  object
# dtypes: float64(4), int64(1), object(12)
# memory usage: 2.4+ MB

# %%
#let's specifically check the null values

dataset.isnull().sum()
# Out:
# Rank                   0
# Name                   0
# Japanese_name      10557
# Type                   0
# Episodes            8994
# Studio              6477
# Release_season     14379
# Tags                 400
# Rating              3131
# Release_year         383
# End_year           15641
# Description            4
# Content_Warning    16655
# Related_Mange      10868
# Related_anime       8432
# Voice_actors        3186
# staff               5490
# dtype: int64

# %%
#let's view the stastical information of our dataset

dataset.describe()
# Out:
#               Rank     Episodes        Rating  Release_year     End_year
# count  18495.00000  9501.000000  15364.000000  18112.000000  2854.000000
# mean    9248.00000    20.920850      3.355133   2006.520318  2004.256132
# std     5339.19095    37.990858      0.400624     15.189537    13.257484
# min        1.00000     1.000000      0.960000   1907.000000  1962.000000
# 25%     4624.50000     2.000000      3.130000   2001.000000  1996.000000
# 50%     9248.00000    12.000000      3.360000   2012.000000  2007.000000
# 75%    13871.50000    26.000000      3.590000   2017.000000  2015.000000
# max    18495.00000   800.000000      4.600000   2023.000000  2022.000000

# %%
min_rating = 0.960000

#Let's view the name of the anime having less rating

min_rated_anime = dataset[dataset.Rating == min_rating]['Name']
print(min_rated_anime)
# Out:
# 15368    Tenkuu Danzai Skelter Heaven
# Name: Name, dtype: object

# %%
#let's view the no.of unique values in Type column

dataset['Type'].nunique()
# Out:
# 8

# %%
#let's view the unique value counts in the 'Type' column

dataset['Type'].value_counts()
# Out:
# TV       5446
# Movie    3577
# Web      2488
# OVA      2235
# Music    2165
# Other     990
# DVD S     911
# TV Sp     683
# Name: Type, dtype: int64

# %%
#let's view the no.of unique values in Studio column

dataset['Studio'].nunique()
# Out:
# 745

# %%
#let's view the unique value counts in the 'Studio' column

dataset['Studio'].value_counts()
# Out:
# Toei Animation       737
# Sunrise              476
# J.C.Staff            382
# TMS Entertainment    364
# MADHOUSE             357
#                     ...
# Studio Shelter         1
# Fall 2005              1
# Studio Bogey           1
# Studio Yamato          1
# Spring 1997            1
# Name: Studio, Length: 745, dtype: int64

# %%
#Let's Select the relevant features for recommendation
selected_features = ['Tags','Type', 'Content_Warning', 'Voice_actors', 'Related_Mange', 'Related_anime']

# %%
#let's Display the selected columns only

dataset[selected_features].head(10)
# Out:
#                                                 Tags   Type  \
# 0  Action, Adventure, Fantasy, Shounen, Demons, H...  TV
# 1  Drama, Fantasy, Romance, Shoujo, Animal Transf...  TV
# 2  Fantasy, Ancient China, Chinese Animation, Cul...  Web
# 3  Action, Adventure, Drama, Fantasy, Mystery, Sh...  TV
# 4  Action, Fantasy, Horror, Shounen, Dark Fantasy...  TV
# 5  Action, Horror, Shounen, Curse, Exorcists, Mon...  TV
# 6  Action, Drama, Fantasy, Horror, Shounen, Dark ...  TV
# 7  Action, Drama, Fantasy, Horror, Shounen, Dark ...  TV
# 8  Action, Drama, Fantasy, Shounen, Demons, Histo...  Movie
# 9  Shounen, Sports, Animeism, School Club, School...  TV
#
#                                      Content_Warning  \
# 0                                  Explicit Violence
# 1  Emotional Abuse,, Mature Themes,, Physical Abu...
# 2                                                NaN
# 3  Animal Abuse,, Mature Themes,, Violence,, Dome...
# 4                    Cannibalism,, Explicit Violence
# 5                                  Explicit Violence
# 6                                                NaN
# 7  Explicit Violence,, Mature Themes,, Physical A...
# 8                 Mature Themes,, Suicide,, Violence
# 9                                                NaN
#
#                                         Voice_actors  \
# 0  Inosuke Hashibira : Yoshitsugu Matsuoka, Nezuk...
# 1  Akito Sohma : Maaya Sakamoto, Kyo Sohma : Yuum...
# 2  Lan Wangji, Wei Wuxian, Jiang Cheng, Jin Guang...
# 3  Alphonse Elric : Rie Kugimiya, Edward Elric : ...
# 4  Armin Arlelt : Marina Inoue, Eren Jaeger : Yuu...
# 5  Megumi Fushiguro : Yuuma Uchida, Nobara Kugisa...
# 6  Armin Arlelt : Marina Inoue, Eren Jaeger : Yuu...
# 7  Eren Jaeger : Yuuki Kaji, Armin Arlelt : Marin...
# 8  Inosuke Hashibira : Yoshitsugu Matsuoka, Kyouj...
# 9  Shoyo Hinata : Ayumu Murase, Tobio Kageyama : ...
#
#                                        Related_Mange  \
# 0                     Demon Slayer: Kimetsu no Yaiba
# 1               Fruits Basket, Fruits Basket Another
# 2  Grandmaster of Demonic Cultivation: Mo Dao Zu ...
# 3  Fullmetal Alchemist, Fullmetal Alchemist (Ligh...
# 4  Attack on Titan, Attack on Titan: End of the W...
# 5                   Jujutsu Kaisen 0, Jujutsu Kaisen
# 6                                    Attack on Titan
# 7                                    Attack on Titan
# 8  Gotouge Koyoharu Tanpenshuu, Demon Slayer: Kim...
# 9         Haikyuu!! (Pilot), Haikyuu!!, Haikyuu-bu!!
#
#                                        Related_anime
# 0  Demon Slayer: Kimetsu no Yaiba, Demon Slayer: ...
# 1  Fruits Basket 1st Season, Fruits Basket 2nd Se...
# 2                   Mo Dao Zu Shi 2, Mo Dao Zu Shi Q
# 3  Fullmetal Alchemist: Brotherhood Specials, Ful...
# 4  Attack on Titan, Attack on Titan 2nd Season, A...
# 5  Jujutsu Kaisen (2018), Juju Sanpo, Eve: Kaikai...
# 6  Attack on Titan, Attack on Titan 2nd Season, A...
# 7  Attack on Titan, Attack on Titan 2nd Season, A...
# 8  Demon Slayer: Kimetsu no Yaiba, Demon Slayer: ...
# 9  Haikyuu!!, Haikyuu!! Lev Kenzan!, Haikyuu!! Se...

# %%
#let's check Null Values in selected columns 
dataset[selected_features].isna().sum()
# Out:
# Tags                 400
# Type                   0
# Content_Warning    16655
# Voice_actors        3186
# Related_Mange      10868
# Related_anime       8432
# dtype: int64

# %%
#Replacing the null values with null string

for feature in selected_features:
  dataset[feature] = dataset[feature].fillna('')

#now let's view the dataset again after filling the missing values
dataset[selected_features].head(10)
# Out:
#                                                 Tags   Type  \
# 0  Action, Adventure, Fantasy, Shounen, Demons, H...  TV
# 1  Drama, Fantasy, Romance, Shoujo, Animal Transf...  TV
# 2  Fantasy, Ancient China, Chinese Animation, Cul...  Web
# 3  Action, Adventure, Drama, Fantasy, Mystery, Sh...  TV
# 4  Action, Fantasy, Horror, Shounen, Dark Fantasy...  TV
# 5  Action, Horror, Shounen, Curse, Exorcists, Mon...  TV
# 6  Action, Drama, Fantasy, Horror, Shounen, Dark ...  TV
# 7  Action, Drama, Fantasy, Horror, Shounen, Dark ...  TV
# 8  Action, Drama, Fantasy, Shounen, Demons, Histo...  Movie
# 9  Shounen, Sports, Animeism, School Club, School...  TV
#
#                                      Content_Warning  \
# 0                                  Explicit Violence
# 1  Emotional Abuse,, Mature Themes,, Physical Abu...
# 2
# 3  Animal Abuse,, Mature Themes,, Violence,, Dome...
# 4                    Cannibalism,, Explicit Violence
# 5                                  Explicit Violence
# 6
# 7  Explicit Violence,, Mature Themes,, Physical A...
# 8                 Mature Themes,, Suicide,, Violence
# 9
#
#                                         Voice_actors  \
# 0  Inosuke Hashibira : Yoshitsugu Matsuoka, Nezuk...
# 1  Akito Sohma : Maaya Sakamoto, Kyo Sohma : Yuum...
# 2  Lan Wangji, Wei Wuxian, Jiang Cheng, Jin Guang...
# 3  Alphonse Elric : Rie Kugimiya, Edward Elric : ...
# 4  Armin Arlelt : Marina Inoue, Eren Jaeger : Yuu...
# 5  Megumi Fushiguro : Yuuma Uchida, Nobara Kugisa...
# 6  Armin Arlelt : Marina Inoue, Eren Jaeger : Yuu...
# 7  Eren Jaeger : Yuuki Kaji, Armin Arlelt : Marin...
# 8  Inosuke Hashibira : Yoshitsugu Matsuoka, Kyouj...
# 9  Shoyo Hinata : Ayumu Murase, Tobio Kageyama : ...
#
#                                        Related_Mange  \
# 0                     Demon Slayer: Kimetsu no Yaiba
# 1               Fruits Basket, Fruits Basket Another
# 2  Grandmaster of Demonic Cultivation: Mo Dao Zu ...
# 3  Fullmetal Alchemist, Fullmetal Alchemist (Ligh...
# 4  Attack on Titan, Attack on Titan: End of the W...
# 5                   Jujutsu Kaisen 0, Jujutsu Kaisen
# 6                                    Attack on Titan
# 7                                    Attack on Titan
# 8  Gotouge Koyoharu Tanpenshuu, Demon Slayer: Kim...
# 9         Haikyuu!! (Pilot), Haikyuu!!, Haikyuu-bu!!
#
#                                        Related_anime
# 0  Demon Slayer: Kimetsu no Yaiba, Demon Slayer: ...
# 1  Fruits Basket 1st Season, Fruits Basket 2nd Se...
# 2                   Mo Dao Zu Shi 2, Mo Dao Zu Shi Q
# 3  Fullmetal Alchemist: Brotherhood Specials, Ful...
# 4  Attack on Titan, Attack on Titan 2nd Season, A...
# 5  Jujutsu Kaisen (2018), Juju Sanpo, Eve: Kaikai...
# 6  Attack on Titan, Attack on Titan 2nd Season, A...
# 7  Attack on Titan, Attack on Titan 2nd Season, A...
# 8  Demon Slayer: Kimetsu no Yaiba, Demon Slayer: ...
# 9  Haikyuu!!, Haikyuu!! Lev Kenzan!, Haikyuu!! Se...

# %%
#let's view the no.of rows and columns : shape

dataset[selected_features].shape
# Out:
# (18495, 6)

# %%
#Combining all the 5 selected features

combined_features = dataset['Tags']+' '+dataset['Type']+' '+dataset['Content_Warning']+' '+dataset['Voice_actors']+' '+dataset['Related_Mange']+' '+dataset['Related_anime']
combined_features
# Out:
# 0        Action, Adventure, Fantasy, Shounen, Demons, H...
# 1        Drama, Fantasy, Romance, Shoujo, Animal Transf...
# 2        Fantasy, Ancient China, Chinese Animation, Cul...
# 3        Action, Adventure, Drama, Fantasy, Mystery, Sh...
# 4        Action, Fantasy, Horror, Shounen, Dark Fantasy...
#                                ...
# 18490    Action, Ancient China, Chinese Animation, Hist...
# 18491                          Chinese Animation TV
# 18492    Chinese Animation, Family Friendly, Short Epis...
# 18493    Chinese Animation, Family Friendly, Short Epis...
# 18494    Comedy, Slice of Life, Dogs Movie    Heisei In...
# Length: 18495, dtype: object

# %%
#let's now view the combined_features' shape

combined_features.shape
# Out:
# (18495,)

# %%
#now let's convert the text data to feature vectors, to find the cosine similarity 
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
feature_vectors = vectorizer.fit_transform(combined_features)

print(feature_vectors)
# Out:
#   (0, 37112)	0.17553082272799386
#   (0, 24908)	0.198423243547306
#   (0, 24858)	0.028371916747573223
#   (0, 39394)	0.34244816187356303
#   (0, 26402)	0.12111099306578915
#   (0, 18803)	0.4379211035696903
#   (0, 33715)	0.3903732608587652
#   (0, 7671)	0.2796679903339309
#   (0, 28417)	0.05329102574024195
#   (0, 33898)	0.04887670337277681
#   (0, 726)	0.099211621773653
#   (0, 7768)	0.023605824427635997
#   (0, 5536)	0.02366683625825516
#   (0, 22919)	0.07887022120112676
#   (0, 7968)	0.018465775286738234
#   (0, 34025)	0.10107981959088336
#   (0, 13379)	0.08262908078390495
#   (0, 6808)	0.029020217043330004
#   (0, 27622)	0.024571378546623446
#   (0, 12161)	0.11439422781776977
#   (0, 20010)	0.11439422781776977
#   (0, 37657)	0.11439422781776977
#   (0, 1421)	0.08506106847065786
#   (0, 15907)	0.060063390018704935
#   (0, 1002)	0.09547044114614504
#   :	:
#   (18491, 37607)	0.4535260910818358
#   (18492, 9291)	0.4069843006486021
#   (18492, 33240)	0.40184033311831224
#   (18492, 10400)	0.39293380153157054
#   (18492, 9753)	0.3860411653946236
#   (18492, 5836)	0.4397445032598664
#   (18492, 1727)	0.31637751495343686
#   (18492, 37607)	0.27566902587026815
#   (18493, 9291)	0.4069843006486021
#   (18493, 33240)	0.40184033311831224
#   (18493, 10400)	0.39293380153157054
#   (18493, 9753)	0.3860411653946236
#   (18493, 5836)	0.4397445032598664
#   (18493, 1727)	0.31637751495343686
#   (18493, 37607)	0.27566902587026815
#   (18494, 13726)	0.4927321922129774
#   (18494, 15724)	0.43810520800447883
#   (18494, 8093)	0.33231015986049073
#   (18494, 24577)	0.31731322503024934
#   (18494, 4466)	0.4672801122666831
#   (18494, 33728)	0.21290684697626475
#   (18494, 6517)	0.13947077093900975
#   (18494, 21324)	0.16712290672538332
#   (18494, 26943)	0.15608911504013734
#   (18494, 24858)	0.13687616961592988

# %%
#let's view the shape of this feature_vectors

feature_vectors.shape
# Out:
# (18495, 40946)

# %%
#now let's get the similarity scores using cosine similarity

from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(feature_vectors)
print(similarity)
# Out:
# [[1.         0.02277279 0.00635855 ... 0.00695984 0.00695984 0.00388344]
#  [0.02277279 1.         0.02227394 ... 0.01349398 0.01349398 0.        ]
#  [0.00635855 0.02227394 1.         ... 0.03974567 0.03974567 0.01113746]
#  ...
#  [0.00695984 0.01349398 0.03974567 ... 1.         1.         0.        ]
#  [0.00695984 0.01349398 0.03974567 ... 1.         1.         0.        ]
#  [0.00388344 0.         0.01113746 ... 0.         0.         1.        ]]

# %%
#let's view the shape of similarity values

similarity.shape
# Out:
# (18495, 18495)

# %%
#let's Create a list with all the anime names given in the dataset

list_of_all_titles = dataset['Name'].tolist()
print(list_of_all_titles)
# Out:
# ['Demon Slayer: Kimetsu no Yaiba - Entertainment District Arc', 'Fruits Basket the Final Season', 'Mo Dao Zu Shi 3', 'Fullmetal Alchemist: Brotherhood', 'Attack on Titan 3rd Season: Part II', 'Jujutsu Kaisen', 'Attack on Titan The Final Season: Part II', 'Attack on Titan The Final Season', 'Demon Slayer: Kimetsu no Yaiba Movie - Mugen Train', 'Haikyuu!! Karasuno High School vs Shiratorizawa Academy', 'your name.', 'Haikyuu!! Second Season', 'Demon Slayer: Kimetsu no Yaiba', 'Hunter x Hunter (2011)', 'A Silent Voice', 'Violet Evergarden Movie', 'Haikyuu!! To the Top: Part II', "Heaven Official's Blessing Special", 'That Time I Got Reincarnated as a Slime Season 2', 'Given', 'Code Geass: Lelouch of the Rebellion R2', 'Mo Dao Zu Shi 2', 'Gintama: The Very Final', 'Link Click', 'Mob Psycho 100 II', 'Haikyuu!! To the Top', 'Fruits Basket 2nd Season', 'The Promised Neverland', 'Spirited Away', 'That Time I Got Reincarnated as a Slime Season 2: Part II', "Heaven Official's Blessing", 'Ranking of Kings', 'Mushoku Tensei: Jobless Reincarnation - Part II', 'Gintama.: Shirogane no Tamashii-hen 2', 'Clannad After Story', 'Mo Dao Zu Shi', "Gintama': Enchousen", 'Banana Fish', 'Douluo Dalu 2', 'Gintama Kanketsu-hen: Yorozuya yo Eien Nare', 'Gintama.', 'Gintama.: Shirogane no Tamashii-hen', 'Attack on Titan 3rd Season', 'Steins;Gate', 'Haikyuu!!', "Gintama'", 'One-Punch Man', 'Demon Slayer: Kimetsu no Yaiba - Mugen Train', 'Gintama°', "Howl's Moving Castle", "Natsume's Book of Friends Season 6", "JoJo's Bizarre Adventure: Golden Wind", "JoJo's Bizarre Adventure: Stone Ocean", 'Vinland Saga', "Natsume's Book of Friends Season 4", 'Assassination Classroom 2nd Season', "Natsume's Book of Friends Season 5", 'My Hero Academia 3', 'Violet Evergarden', 'That Time I Got Reincarnated as a Slime', 'My Hero Academia 2', 'Wolf Children', 'SK8 the Infinity', 'Hajime no Ippo: The Fighting!', 'Code Geass: Lelouch of the Rebellion', 'JoJo’s Bizarre Adventure: Stardust Crusaders - Battle in Egypt', 'Yona of the Dawn: Zeno Arc', "JoJo's Bizarre Adventure: Diamond is Unbreakable", 'Kamisama Kiss: Kako-hen', 'Hajime no Ippo: New Challenger', 'Mushishi Zoku Shou 2nd Season', 'Attack on Titan', 'Haikyuu!! Tokushuu! Harukou Volley ni Kaketa Seishun', 'Kaguya-sama: Love Is War?', 'Gintama: Porori-hen', 'March Comes in like a Lion 2nd Season', "Natsume's Book of Friends Season 3", 'Attack on Titan 2nd Season', 'I Want to Eat Your Pancreas', 'Rascal Does Not Dream of a Dreaming Girl', 'Given Movie', 'Mushishi Zoku Shou', 'Princess Mononoke', "Kuroko's Basketball 3", 'BTS: We are Bulletproof - the Eternal', 'Haikyuu!! Movie 4: Battle of Concepts', 'Dr. Stone', 'Attack on Titan: No Regrets', 'Horimiya', 'Cowboy Bebop', 'Hotarubi no Mori e', 'The Disastrous Life of Saiki K. 2nd Season', 'Monogatari Series: Second Season', 'Castlevania Season 4', 'Doukyuusei', 'ERASED', 'The Rising of the Shield Hero', 'To Your Eternity', 'Hajime no Ippo: Rising', 'Josee, the Tiger and the Fish', 'Made in Abyss', 'Rurouni Kenshin: Tsuiokuhen', 'Descending Stories: Shouwa Genroku Rakugo Shinjuu', 'Haikyuu!! Movie 3: Talent and Sense', 'Mo Dao Zu Shi Q', "Natsume's Book of Friends Season 2", 'Made in Abyss Movie: Dawn of the Deep Soul', 'Fruits Basket 1st Season', 'Kizumonogatari Part 3: Reiketsu', 'Dr. Stone: Stone Wars', 'My Hero Academia 4', 'Owarimonogatari II', 'Great Teacher Onizuka', 'Your lie in April', 'Bungo Stray Dogs 3rd Season', 'Kamisama Kiss 2nd Season', 'Violet Evergarden: Eternity and the Auto Memory Doll', 'Mob Psycho 100', "Natsume's Book of Friends Season 6 Specials", "Kuroko's Basketball 2", "Natsume's Book of Friends Movie: Ephemeral Bond", 'Odd Taxi', 'The Legend of Hei', 'Death Note', 'Moriarty the Patriot 2nd Season', "Fate/stay night: Heaven's Feel III. spring song", 'One Piece Movie 14: Stampede', 'Kingdom 3', 'One Piece', 'Mushishi: Hihamukage', 'Tokyo Revengers', 'My Hero Academia Movie 2: Heroes:Rising', 'Fate/Zero 2', 'My Hero Academia', 'Steins;Gate Movie: L ...

# %%
#let's view the length of the list

len(list_of_all_titles)
# Out:
# 18495

# %%
#Enter a anime name to find animes which are similar to that name entered
anime_name = input(' Enter your favourite anime name : ')
# Out:
#  Enter your favourite anime name : Goblin Slayer

# %%
#Let's find the close match for the anime name given by the user

import difflib
find_close_match = difflib.get_close_matches(anime_name, list_of_all_titles)
print(find_close_match)
# Out:
# ['Goblin Slayer', 'Goblin Slayer 2', 'Goblin Slayer PV']

# %%
#Display the close match 
close_match = find_close_match[0]
print(close_match)
# Out:
# Goblin Slayer

# %%
#Finding the index of the nime with the title
index_of_the_anime = dataset[dataset.Name == close_match]['Rank'].values[0]
print(index_of_the_anime)
# Out:
# 776

# %%
#here 775 is the serial no. starting from 0(index number)

dataset.Rank[775]
# Out:
# 776

# %%
#now let's Get the similarity row for the selected index 
#These will be the similarity values for the movie entered by the user 

similarity_score = list(enumerate(similarity[index_of_the_anime]))
print(similarity_score)
# Out:
# [(0, 0.007966087079151927), (1, 0.020322447159423388), (2, 0.008533558841007679), (3, 0.017944952399110998), (4, 0.006537517330891695), (5, 0.044142414287267465), (6, 0.015497344765514379), (7, 0.014244703254741992), (8, 0.013277180033321869), (9, 0.013442570308015322), (10, 0.025156505869397917), (11, 0.018364740042839073), (12, 0.01205038419076037), (13, 0.014549459750965525), (14, 0.031127210735230105), (15, 0.012409938557440775), (16, 0.023657478860669698), (17, 0.030740837637859515), (18, 0.003956658512863833), (19, 0.03982183028980896), (20, 0.015449267652431303), (21, 0.011035293578790777), (22, 0.0098775657752283), (23, 0.01041496656938727), (24, 0.04432858027864866), (25, 0.021919295383247016), (26, 0.018429455838495402), (27, 0.026277922976548594), (28, 0.03801076899513908), (29, 0.011385504841952403), (30, 0.033429245064934124), (31, 0.024990869702956574), (32, 0.004831161350968242), (33, 0.030653002197757725), (34, 0.03610193859208602), (35, 0.012416746773904374), (36, 0.0095580220955342), (37, 0.028939690846016258), (38, 0.0051178035923343), (39, 0.027030039951637854), (40, 0.010216063112312863), (41, 0.03025401223948295), (42, 0.006885573980493601), (43, 0.01318985835649604), (44, 0.021314622175895588), (45, 0.011565198858171756), (46, 0.12037317280828576), (47, 0.004389979473412593), (48, 0.01018087969102892), (49, 0.025728045665804875), (50, 0.011835830212971452), (51, 0.0075694367187419676), (52, 0.011240162922527297), (53, 0.027694214900430537), (54, 0.015721347209209563), (55, 0.012278063612717785), (56, 0.011768167690516777), (57, 0.02339200272299568), (58, 0.01605720939917184), (59, 0.005344044358444143), (60, 0.009383169888909346), (61, 0.031674313039215064), (62, 0.022155663180434184), (63, 0.01312041984600478), (64, 0.015064939261337411), (65, 0.004334091987727121), (66, 0.04820956551446517), (67, 0.0041096509467136826), (68, 0.011431385727523063), (69, 0.01525977307536088), (70, 0.012567932397717368), (71, 0.012286917355822609), (72, 0.025582022925916326), (73, 0.03625546361703586), (74, 0.010942699256937584), (75, 0.02937036271361798), (76, 0.01305522892784168), (77, 0.007789864908499271), (78, 0.03923019332011907), (79, 0.03558909333980269), (80, 0.023824343907790133), (81, 0.01214579666089758), (82, 0.020597473098806322), (83, 0.005034872948217338), (84, 0.0), (85, 0.019203146709185603), (86, 0.02842237946756139), (87, 0.00916900226450653), (88, 0.017308276461269336), (89, 0.021650414300081806), (90, 0.03049889727536196), (91, 0.01354812434463139), (92, 0.023034372793378916), (93, 0.022488139766694087), (94, 0.04192876377557083), (95, 0.043521795234265276), (96, 0.023464826804103167), (97, 0.022080898561346828), (98, 0.01596935793247829), (99, 0.023998485790229535), (100, 0.01763383666185803), (101, 0.0072634902465233304), (102, 0.024149811704421896), (103, 0.011425364733166927), (104, 0.0038034386640505664), (105, 0.015699201706972657), (106, 0.010903458850276663), (107, 0.025680407350877347), (108, 0.039759137455757196), (109, 0.03445624339550331), (110, 0.012603914784984353), (111, 0.02587260672239493), (112, 0.01641302129132892), (113, 0.03488019744834226), (114, 0.029709522987237228), (115, 0.012580591863233025), (116, 0.010041773964879111), (117, 0.04251688142911456), (118, 0.020532809916590407), (119, 0.006694737650639642), (120, 0.015410119568161105), (121, 0.03504876701212353), (122, 0.002418921942368915), (123, 0.10745503528259354), (124, 0.03872290505016089), (125, 0.0074222699662290035), (126, 0.019987837067627433), (127, 0.030021877532772023), (128, 0.005342828265444595), (129, 0.011229933033033308), (130, 0.01608196492877941), (131, 0.014239211521126305), (132, 0.0029023637329153953), (133, 0.008772292571271982), (134, 0.012752722238375046), (135, 0.003939562068062509), (136, 0.023756295458934894), (137, 0.013524454261813843), (138, 0.018053277322294232), (139, 0.042013197193889934), (140, 0.016905020763814237), (141, 0.017464001721471632), (142, 0.01599370379941083), (143, 0.019303313 ...

# %%
#Length of Similarity Score 

len(similarity_score)
# Out:
# 18495

# %%
#now let's sort the animes based on their similarity score

sorted_similar_animes = sorted(similarity_score, key = lambda x:x[1], reverse = True)
print(sorted_similar_animes)
# Out:
# [(776, 1.0), (358, 0.5325471320251958), (16424, 0.24833029870412643), (14732, 0.23905936860654065), (12728, 0.21876806125366685), (6356, 0.2063076029954719), (2599, 0.20285404500722576), (4537, 0.1873888698663106), (1652, 0.18672956593614337), (14670, 0.18322775556010032), (18446, 0.170354674983398), (15253, 0.16351080304915588), (15140, 0.1614192986353963), (11509, 0.15358014865391578), (7056, 0.1530663300048976), (4597, 0.14919199143210043), (2311, 0.14381758045195767), (13739, 0.14349676147415624), (15340, 0.1425891869674832), (9349, 0.14227064114390905), (2005, 0.1392675655865469), (13612, 0.1381863936532685), (10406, 0.13783979619335748), (14127, 0.13722884994879525), (15043, 0.1366969006200837), (14539, 0.13630067071873284), (16663, 0.1356943855185195), (1302, 0.13498289591126764), (12550, 0.13490547764684693), (3142, 0.13440988299698373), (15287, 0.13241379667119688), (15363, 0.13008487159326698), (15265, 0.12943520850867393), (3267, 0.12792563208927377), (8321, 0.1270220157565882), (10603, 0.1255109752806952), (13250, 0.12379181143362233), (10905, 0.12357486700041913), (15833, 0.12313104197892837), (17037, 0.12289862682019885), (3834, 0.12214855091280999), (16695, 0.12213723149280423), (8653, 0.12207044318306856), (9283, 0.12168127154162552), (11917, 0.12108429040166954), (5887, 0.12045209014306232), (46, 0.12037317280828576), (15108, 0.12012482111564127), (4960, 0.11948888065949845), (14719, 0.119129112416331), (3844, 0.11879815501401109), (3473, 0.1179853358147566), (11283, 0.1179163564131274), (11610, 0.1177896290494108), (16298, 0.117641811142219), (9869, 0.11722339588108971), (18195, 0.11660358174693933), (14589, 0.11559064490939387), (14364, 0.11544761995074737), (11007, 0.11512502886233608), (8096, 0.1148261048334436), (1753, 0.11391331843721429), (6002, 0.11382672830582101), (14063, 0.1129093432509205), (2000, 0.1126738827145686), (5174, 0.1126700361815635), (12043, 0.11226392691513232), (6284, 0.11206914696548291), (9896, 0.11176668057199911), (14001, 0.11132664234345457), (13424, 0.11110202086759283), (8111, 0.11044540803639397), (817, 0.11009937699667692), (521, 0.10957788494478891), (14073, 0.10927676102738444), (10359, 0.10880943298705753), (2308, 0.10840856786573226), (10768, 0.10839054609143946), (123, 0.10745503528259354), (14964, 0.10708278253112574), (13786, 0.10669924984704203), (13560, 0.10609568441286302), (14774, 0.10604789888933472), (12667, 0.10548879985075424), (7949, 0.1054507530448293), (14224, 0.10539386891915485), (1201, 0.10478833991505235), (15226, 0.10471788491597397), (15251, 0.10418560128166493), (16464, 0.10414689766949409), (661, 0.10391463528103143), (16905, 0.10357371413590005), (18376, 0.10348481299808085), (7889, 0.10325695667880554), (2655, 0.10317042702771394), (9176, 0.10274465885991561), (15241, 0.1026181177967276), (13144, 0.1025320171053186), (13668, 0.10250670325242693), (15541, 0.10241918180921987), (15742, 0.10239560793169097), (777, 0.10196605050869739), (2122, 0.10164239726668384), (14948, 0.10111707994707131), (8205, 0.10110585705798464), (14649, 0.10086175247679309), (419, 0.10077146763218758), (9398, 0.10012607307509062), (11422, 0.09994300416717598), (1408, 0.09983682936230891), (15215, 0.09889212208062276), (1932, 0.09870884976457257), (586, 0.09870708917363019), (14095, 0.0986493343461792), (15044, 0.09860348494436015), (15292, 0.0985380223893183), (4223, 0.09850712246269404), (4314, 0.09824141787738187), (630, 0.09779770002049329), (10350, 0.09748703031350317), (3195, 0.09738595816801096), (12165, 0.09708714785215757), (14039, 0.0968855182622396), (6813, 0.09684988792759835), (14429, 0.09645137982011326), (15175, 0.09641851906180328), (8334, 0.09610567263202838), (3630, 0.09605010591004819), (14033, 0.0957399550562475), (15045, 0.0957399550562475), (9662, 0.0954955425583783), (15898, 0.09521871221739175), (11408, 0.09509874593573109), (1116, 0.09447778051538185), (1276, 0.09437664358579333), (14278, 0.09399837154412452), (14529, 0.09399837154412452), (14945, 0.0 ...

# %%
#let's replace the index of the dataframe with the rank

#dataset = dataset.set_index([pd.Index('Rank')])

# %%
#After the sorting, let's now recommend(print) the names of the similar animes based on their index

print('Animes suggested for you are: \n')

i=1
for movie in sorted_similar_animes:
  index = movie[0]    #taking only the index value but not the score
  title_from_index = dataset[dataset.Rank==index]['Name'].values[0]
  if(i<11):
    print(i,'.', title_from_index)
    i+=1
# Out:
# Animes suggested for you are:
#
# 1 . Goblin Slayer
# 2 . Detective Conan Movie 15: Quarter of Silence
# 3 . Shenmue the Animation
# 4 . Hyadain: Kara-age-kun Ondo 2012
# 5 . Kamigami no Ki
# 6 . Tonagura!
# 7 . Sound! Euphonium: Ready, Set, Monaka
# 8 . Tensei Shoya kara Musabori H: Ouji no Honmei wa Akuyaku Reijou
# 9 . Jewelpet Twinkle Special
# 10 . Navia Dratp
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-d0d450a36994> in <module>
#       6 for movie in sorted_similar_animes:
#       7   index = movie[0]    #taking only the index value but not the score
# ----> 8   title_from_index = dataset[dataset.Rank==index]['Name'].values[0]
#       9   if(i<11):
#      10     print(i,'.', title_from_index)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
